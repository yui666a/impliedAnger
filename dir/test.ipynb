# %%
import pandas as pd
import torch


print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.device_count())
# Out:
# 1.13.1+cu117
# False
# 0
# /home/nb-user/.local/lib/python3.8/site-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
from pyknp import Juman
jumanpp = Juman()
aaaaa = jumanpp.analysis("すもももももももものうち")
for mrph in aaaaa.mrph_list(): # 各形態素にアクセス
    print("見出し:%s, 読み:%s, 原形:%s, 品詞:%s, 品詞細分類:%s, 活用型:%s, 活用形:%s, 意味情報:%s, 代表表記:%s" \
            % (mrph.midasi, mrph.yomi, mrph.genkei, mrph.hinsi, mrph.bunrui, mrph.katuyou1, mrph.katuyou2, mrph.imis, mrph.repname))
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 見出し:すもも, 読み:すもも, 原形:すもも, 品詞:名詞, 品詞細分類:普通名詞, 活用型:*, 活用形:*, 意味情報:自動獲得:テキスト, 代表表記:
# 見出し:も, 読み:も, 原形:も, 品詞:助詞, 品詞細分類:副助詞, 活用型:*, 活用形:*, 意味情報:NIL, 代表表記:
# 見出し:もも, 読み:もも, 原形:もも, 品詞:名詞, 品詞細分類:普通名詞, 活用型:*, 活用形:*, 意味情報:代表表記:桃/もも ドメイン:料理・食事 カテゴリ:植物;人工物-食べ物 漢字読み:訓, 代表表記:桃/もも
# 見出し:も, 読み:も, 原形:も, 品詞:助詞, 品詞細分類:副助詞, 活用型:*, 活用形:*, 意味情報:NIL, 代表表記:
# 見出し:もも, 読み:もも, 原形:もも, 品詞:名詞, 品詞細分類:普通名詞, 活用型:*, 活用形:*, 意味情報:代表表記:桃/もも ドメイン:料理・食事 カテゴリ:植物;人工物-食べ物 漢字読み:訓, 代表表記:桃/もも
# 見出し:の, 読み:の, 原形:の, 品詞:助詞, 品詞細分類:接続助詞, 活用型:*, 活用形:*, 意味情報:NIL, 代表表記:
# 見出し:うち, 読み:うち, 原形:うち, 品詞:名詞, 品詞細分類:副詞的名詞, 活用型:*, 活用形:*, 意味情報:代表表記:うち/うち, 代表表記:うち/うち

# %%
df_none = pd.read_csv('ksl_pub/suggestive_anger/data/fuman_survey/csv/0.csv')
a = df_none["feature"].values.tolist()
a
# Out:
# ['ヤクルトの舌や喉に何か残る感じの、あれは何でしょう?すごくいやだ。',
#  '最近の雑誌は高い中身の内容薄いのに千円近くするおまけもいらない',
#  '髪の長い男の店員がいる。不潔。',
#  '殺人的に混んでる朝の通勤時間帯に、自分の居場所を確保しようとして、意地でも一歩もどかない人。ひじで人をどかそうとまでする。本当にムカつく_____',
#  '手拭いの種類が豊富だが、柄がダサい。',
#  'ぺヤング パック焼きそば 友人が大人買いしているが、どこが美味しいのか理解できない。いたって普通の味では。',
#  '伊方原発が再稼動!!_  得をするのは誰?',
#  'こわい、野放しだからって非常識、古すぎる家ががたがたいって恐怖だ。',
#  'スポーツ興味ない、みんみん打破とかがが1割増しで売れてる?どーでもいいわ。',
#  '何であんなに甘くするのか理解不能',
#  '公園の回りで路駐してる奴等に不満!!暑いからエンジンかけっぱで居るから、近くのベンチは暑くて座れない!!',
#  'まわす蓋は朝とか面倒臭いし閉める時に落としやすいから嫌だ',
#  '男性で足を開いて座る人。非常識。',
#  '電車の中で、いいとしこいた主婦友達同士が、ピーチクパーチク声が大きい。あんたら、自分まだ若いと思ってんのかしらないけど、周りから見たら十分おばさんですよ。大人げないわ。ださ。',
#  '夫。県外の人を馬鹿にするやつ。親元離れて頑張ってるとか思えないのか。最低',
#  '産後2ヶ月で、親戚が出勤。狂ってる。しかも、女上司が1番敵らしい。',
#  '愛媛県の伊方原発再開。オリンピック開催中に再開というタイミングは、報道が大きくならないための策としか思えない。コソコソしてる感じが不快。間違ったことしてないんだろ?やるなら堂々とやれよ。何かあったら瀬戸内海と周辺海域は壊滅するけどな。内海だから福島より酷いことになると思うけどな。',
#  'ポケモンgoをやる人が増えて、ごみをそこらに捨てる人が多くなった。',
#  '喫煙ルーム臭いきつすぎて嫌です',
#  '本当に毎日多すぎ。配信停止出来ない。',
#  '高い、狭い、古い。なんとかならないのか。',
# ...

# %%
import torch
from transformers import AutoTokenizer, AutoModelForMaskedLM

ja_models = ["nlp-waseda/roberta-base-japanese","nlp-waseda/roberta-large-japanese","nlp-waseda/roberta-large-japanese-seq512"]
ja_model = ja_models[1]

tokenizer =    AutoTokenizer.from_pretrained(ja_model)
model = AutoModelForMaskedLM.from_pretrained(ja_model)
# Out:
# 2023-01-27 14:57:00.144799: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-27 14:57:01.973276: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-01-27 14:57:01.973384: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
sampletxts = ["こんにちはいい天気ですね。", 
              "明日は雨になるそうです。",
              "昨日からお腹が痛いです。",
              "今年の冬は暖冬だそうです。",
              "体調が良くなってきました。"]

result = [tokenizer.tokenize(txt) for txt in a]
result
# Out:
# [['▁ヤクルト',
#   'の',
#   '舌',
#   'や',
#   '喉',
#   'に',
#   '何',
#   'か',
#   '残',
#   'る',
#   '感',
#   'じ',
#   'の',
#   '、',
#   'あ',
#   'れ',
#   'は',
#   '何',
#   'でしょう',
#   '?',
#   'す',
#   'ごく',
#   'い',
#   'や',
#   'だ',
#   '。'],
#  ['▁最近',
#   'の',
#   '雑',
#   '誌',
#   'は',
#   '高い',
#   '中',
#   '身',
#   'の',
#   '内',
#   '容',
#   '薄',
#   'い',
#   'の',
#   'に',
#   '千',
#   '円',
#   '近',
#   'く',
#   'する',
#   'お',
#   'ま',
#   'け',
#   'も',
#   'い',
#   'ら',
#   'ない'],
#  ['▁髪', 'の', '長', 'い', '男', 'の', '店', '員', 'がい', 'る', '。', '不', '潔', '。'],
#  ['▁殺人',
#   '的',
#   'に',
#   '混',
#   'んで',
#   'る',
#   '朝',
#   'の',
#   '通',
#   '勤',
#   '時',
#   '間',
#   '帯',
#   'に',
#   '、',
#   '自',
#   '分の',
#   '居',
#   '場',
#   '所',
#   'を',
#   '確',
#   '保',
#   'し',
#   'よう',
#   'として',
#   '、',
#   '意',
#   '地',
#   'で',
#   'も',
#   '一',
#   '歩',
#   'も',
#   'ど',
#   'か',
#   'ない',
#   '人',
#   '。',
#   'ひ',
#   'じ',
#   'で',
#   '人',
#   'を',
#   'ど',
#   'か',
# ...

# %%
result
